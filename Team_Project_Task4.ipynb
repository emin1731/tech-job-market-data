# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobs = pd.read_csv('/content/drive/MyDrive/jobs.csv')
postings = pd.read_csv('/content/drive/MyDrive/postings.csv')

# Merging the dataframes on job_title
merged_data = pd.merge(jobs, postings, left_on='title', right_on='job_title')

# Grouping by average months of experience
experience_stats = merged_data.groupby('title')['months_experience'].mean().reset_index()

# Selecting top 15 job titles
experience_stats = experience_stats.nlargest(15, 'months_experience')

# Dropping entries with 0 months of experience
experience_stats = experience_stats[experience_stats['months_experience'] != 0]

# Illustration
plt.figure(figsize=(12, 6))

# Average Months of Experience Plot
plt.bar(experience_stats['title'], experience_stats['months_experience'], color='skyblue')
plt.title('Average Months of Experience by Job Title')
plt.ylabel('Average Months of Experience')
plt.xlabel('Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# Analyzing the most in-demand software engineering job titles
job_title_counts = merged_data["title"].value_counts()
# Select the top 30 job titles
top_n_titles = job_title_counts.head(30)

# Drop entries with count below 1 and NaN values
top_n_titles = top_n_titles[top_n_titles >= 1].dropna()

# Take only the top 15 job titles after dropping values below 1 and NaNs
top_n_titles = top_n_titles.nlargest(15)

# Filter out values below 1
top_n_titles = top_n_titles[top_n_titles >= 1]

labels = top_n_titles.index.to_numpy()
sizes = top_n_titles.to_numpy()

# Create pie chart
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.title("Top 15 Job Titles (In Demand)")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# Sample data (job titles and required years of experience)
data = {
    'Job Title': ['Software Engineer', 'Senior Software Engineer', 'Data Analyst', 'Senior Data Analyst'],
    'Years of Experience': [2, 5, 1, 4],  # Sample years of experience required for each job title
    'Job Level': ['Entry-Level', 'Mid-Level', 'Entry-Level', 'Mid-Level']  # Sample job levels
}

# Create DataFrame from sample data
df = pd.DataFrame(data)

# Group data by job level and calculate average years of experience
avg_years_experience = df.groupby('Job Level')['Years of Experience'].mean()

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(avg_years_experience, labels=avg_years_experience.index, autopct='%1.1f%%', startangle=140)
plt.title("Average Years of Experience by Job Level")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobs = pd.read_csv('/content/drive/MyDrive/jobs.csv')
postings = pd.read_csv('/content/drive/MyDrive/postings.csv')



# Grouping by average months of experience for each job title
experience_stats = merged_data.groupby('title')['months_experience'].mean().reset_index()

# Selecting top 15 job titles
experience_stats = experience_stats.nlargest(15, 'months_experience')

# Dropping entries with 0 months of experience
experience_stats = experience_stats[experience_stats['months_experience'] != 0]

# Illustration - Bar chart for top 15 job titles based on average months of experience
plt.figure(figsize=(12, 6))
plt.bar(experience_stats['title'], experience_stats['months_experience'], color='skyblue')
plt.title('Average Months of Experience by Job Title')
plt.ylabel('Average Months of Experience')
plt.xlabel('Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# Grouping by job level and calculating average years of experience
avg_years_experience = merged_data.groupby('Seniority level')['months_experience'].mean().reset_index()

# Sort job levels by average years of experience
avg_years_experience = avg_years_experience.sort_values(by='months_experience', ascending=False)

# Illustration - Bar chart for average years of experience required for different job levels
plt.figure(figsize=(10, 6))
plt.bar(avg_years_experience['Seniority level'], avg_years_experience['months_experience'], color='skyblue')
plt.title('Average Months of Experience Required for Different Job Levels')
plt.xlabel('Seniority Level')
plt.ylabel('Average Months of Experience')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobs = pd.read_csv('/content/drive/MyDrive/jobs.csv')
postings = pd.read_csv('/content/drive/MyDrive/postings.csv')

# Merging the dataframes on job_title
merged_data = pd.merge(jobs, postings, left_on='title', right_on='job_title')

# Grouping by average years of experience
experience_stats = merged_data.groupby('title')['months_experience'].mean().reset_index()

# Illustration
plt.figure(figsize=(12, 6))

# Average Years of Experience Plot
plt.bar(experience_stats['title'], experience_stats['months_experience'], color='skyblue')
plt.title('Average Months of Experience by Job Title')
plt.ylabel('Average Months of Experience')
plt.xlabel('Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# Analyzing the most in-demand software engineering job titles
job_title_counts = merged_data["title"].value_counts()
top_n_titles = job_title_counts.head(10)

labels = top_n_titles.index.to_numpy()
sizes = top_n_titles.to_numpy()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=140)
plt.title("Top Job Titles (In Demand)")
plt.axis("equal")  # Equal aspect ratio ensures a circular pie chart
plt.show()
