# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobs = pd.read_csv('/content/drive/MyDrive/jobs.csv')
postings = pd.read_csv('/content/drive/MyDrive/postings.csv')

# Merging the dataframes on job_title
merged_data = pd.merge(jobs, postings, left_on='title', right_on='job_title')

# Grouping by average months of experience
experience_stats = merged_data.groupby('title')['months_experience'].mean().reset_index()

# Selecting top 15 job titles
experience_stats = experience_stats.nlargest(15, 'months_experience')

# Dropping entries with 0 months of experience
experience_stats = experience_stats[experience_stats['months_experience'] != 0]

# Illustration
plt.figure(figsize=(12, 6))

# Average Months of Experience Plot
plt.bar(experience_stats['title'], experience_stats['months_experience'], color='skyblue')
plt.title('Average Months of Experience by Job Title')
plt.ylabel('Average Months of Experience')
plt.xlabel('Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# Analyzing the most in-demand software engineering job titles
job_title_counts = merged_data["title"].value_counts()
top_n_titles = job_title_counts.head(15)

# Drop entries with 0 count
top_n_titles = top_n_titles[top_n_titles != 0]

labels = top_n_titles.index.to_numpy()
sizes = top_n_titles.to_numpy()

# Drop entries with 0 count and NaN values
top_n_titles = top_n_titles.dropna()

# Create bar chart
plt.figure(figsize=(12, 6))
top_n_titles.plot(kind='bar', color='skyblue')
plt.title("Top 15 Job Titles (In Demand)")
plt.xlabel("Job Titles")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobPostings = pd.read_csv('/content/drive/MyDrive/jobs.csv')
jobPostings2 = pd.read_csv('/content/drive/MyDrive/postings.csv')

# Calculate the average years of experience for each job level

# Plot the results
plt.figure(figsize=(10, 6))
plt.xlabel('Job Level')
plt.ylabel('Average Years of Experience')
plt.title('Average Years of Experience for Different Job Levels')
plt.show()

def calculate_average_experience(jobs):
    # Initialize a dictionary to hold total experience and count for each job level
    job_experience = {}

# Use the function with the data from the DataFrame
jobs = jobPostings.to_dict('records')
print(calculate_average_experience(jobs))
plt.tight_layout()
plt.show()
# Out:
# None

# %%
if jobPostings.empty:
    raise ValueError('The DataFrame is empty.')

# %%
if jobPostings.empty:
    raise ValueError('The DataFrame is empty.')

# %%
# Check if there is a variable named 'job_level' that is not the DataFrame column
if 'job_level' in globals() and job_level is not jobPostings['job_level']:
    raise ValueError('A variable named "job_level" is masking the DataFrame column.')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
jobs = pd.read_csv('/content/drive/MyDrive/jobs.csv')
postings = pd.read_csv('/content/drive/MyDrive/postings.csv')

# Merging the dataframes on job_title
merged_data = pd.merge(jobs, postings, left_on='title', right_on='job_title')

# Grouping by average years of experience
experience_stats = merged_data.groupby('title')['months_experience'].mean().reset_index()

# Illustration
plt.figure(figsize=(12, 6))

# Average Years of Experience Plot
plt.bar(experience_stats['title'], experience_stats['months_experience'], color='skyblue')
plt.title('Average Months of Experience by Job Title')
plt.ylabel('Average Months of Experience')
plt.xlabel('Job Title')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# Analyzing the most in-demand software engineering job titles
job_title_counts = merged_data["title"].value_counts()
top_n_titles = job_title_counts.head(10)

labels = top_n_titles.index.to_numpy()
sizes = top_n_titles.to_numpy()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=140)
plt.title("Top Job Titles (In Demand)")
plt.axis("equal")  # Equal aspect ratio ensures a circular pie chart
plt.show()
